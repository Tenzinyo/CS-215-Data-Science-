# %% [markdown]
# ## Part 1: Exploring the data

# %%
# import the packages we've been using all semester long
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# We'll be working with a dataset on course enrollments from 2000 to 2023 for a subset of Whitman majors

# First, import the data file as a data frame
df_courses = pd.read_excel("whitman-course-sizes-2000-2023.xlsx")
df_courses.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7286 entries, 0 to 7285
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Term                   7286 non-null   object
#  1   Name                   7286 non-null   object
#  2   Short Title            7286 non-null   object
#  3   Subject                7286 non-null   object
#  4   Min Cred               7286 non-null   float64
#  5   Max Cred               1400 non-null   float64
#  6   Capacity               7274 non-null   float64
#  7   Active Students Count  7286 non-null   int64
# dtypes: float64(3), int64(1), object(4)
# memory usage: 455.5+ KB

# %% [markdown]
# **Your task:**
#
# Examine it. Ask yourself: What does each row represent? Then, figure out:

# %%
# How many different majors are there in this data set and which are they?
df_courses['Subject'].unique()
# YOUR CODE HERE
# Out:
# array(['CHEM', 'ECON', 'ENGL', 'JPNS', 'MATH', 'PHIL', 'PSYC', 'CS'],
#       dtype=object)

# %%
# What time period does this data frame cover?
df_courses["Term"].unique()
# YOUR CODE HERE
# Out:
# array(['2000FA', '2001SP', '2001FA', '2002SP', '2002FA', '2003SP',
#        '2003FA', '2004SP', '2004FA', '2005SP', '2005FA', '2006SP',
#        '2006FA', '2007SP', '2007FA', '2008SP', '2008FA', '2009SP',
#        '2009FA', '2010SP', '2010FA', '2011SP', '2011FA', '2012SP',
#        '2012FA', '2013SP', '2013FA', '2014SP', '2014FA', '2015SP',
#        '2015FA', '2016SP', '2016FA', '2017SP', '2017FA', '2018SP',
#        '2018FA', '2019SP', '2019FA', '2020SP', '2020FA', '2021SP',
#        '2021FA', '2022SP', '2022FA', '2023SP'], dtype=object)

# %%
# How many *unique* courses are there?
df_courses['Short Title'].unique()
# YOUR CODE HERE
# Out:
# array(['General Chemistry', 'General Chemistry Lab I',
#        'Advanced General Chem I', 'Adv. General Chem I Lab',
#        'Quant Analys and Chem Equl', 'Quant Anal and Chem Equil Lab',
#        'Organic Chemistry I', 'Physical Chemistry I',
#        'Instrmntl Meth of Analys', 'Instrmntl Meth Analys Lab',
#        'Curr Top: Infectious Diseases', 'Independent Study',
#        'Physical Organic Chemistry', 'Adv Topics in Chemistry',
#        'Research', 'Honors Thesis', 'Principles of Economics',
#        'Statistics for Economics', 'Stats for Economists Lab',
#        'Government and the Economy', 'Intermed Microeconomics',
#        'Intermed Macroeconomics', 'European Economic History',
#        'Monetary Theory and Policy', 'Mathematical Economics',
#        'International Economics', 'Environ and Nat Resrc Econ',
#        'Urban Economics', 'Directed Reading', 'Language and Writing',
#        'Introduction to Fiction', 'Introduction to Drama',
#        'The Shaping Spirit', 'Dostoyevsky and the Outsider',
#        'Expository Writing', 'Creative Writing',
#        'Intro to the Art of the Cinema', 'Approaches to Stdy of Lit',
#        'Advanced Creative Writing', 'Medieval and 16th Cent Lit',
#        'Eighteenth Cent Engl Lit', 'Twentieth Cent Brit Lit',
#        'American Lit to 1865', 'American Lit, 1865-1914', 'Shakespeare',
#        'SS: Magician As Creative Art', 'SS: The Harlem Renaissance',
#        'Sem: Lit, History and Myth', 'Sem: Authors',
#        'Sem: Literary Evaluation', 'Elementary Japanese',
#        'Intermediate Japanese', 'Intro to Mathematical Thinking',
#        'Calculus I', 'Calculus II', 'Programming in C++', 'Calculus III',
#        'Calculus Laboratory', 'Linear Algebra',
#        'Probability and Statistics', 'Operations Research',
#        'Abstract Algebra', 'Numerical Analysis', 'Critical Reasoning',
#        'Problems in Philosophy', 'Ethics', 'Philosophy of Religion',
#        'Philosophy and Literature', 'Epistemology',
#        'Hist and Phil of Science', 'Ancient Philosophy',
#        'Early Modern Philosophy', "PPM: Plato's Republic",
#        'Current Issues in Phil', 'Senior Thesis Research',
#        'Senior Thesis', 'Principles of Psychology',
#        'Appl and Exp Analysis of Bhvr', 'Developmental Psychology',
#        'Peer Counseling', 'Tutorial: History of Psych',
#        'Tutorial: Philos of Psych', 'Tutorial: Psych of Health',
#        'Appl Behavioral Analysis', 'Physiology of Behavior',
#        'Seminar: Life Span Psychology', 'Seminar: Cross Cultural Psyc',
#        'Practicum Experience', 'Personality Theories',
#        'Tutorial: Thry of Learn', 'Tutorial: Exp Analysis Behvr',
#        'Tutorial: Statistical Meth', 'Contemporary and Hst Issues',
#        'Clinical Psychology', 'Thesis', 'Senior Seminar',
#        'Chem in the Natural World', 'General Chemistry Lab II',
#        'Advanced General Chemistry II', 'Adv.General Chem II Lab',
#        'Organic Chemistry II', 'Organic Lab Techniques',
#        'Physical Chemistry II', 'Physical Chemistry Lab',
#        'Financial Accounting', 'American Economic History',
#        'Intro to Econometrics', 'Intro to Financial Econ',
#        'Labor Economics', 'Public Finance', 'Open-Economy Macroeconomics',
#        'Law and Economics', 'Introduction to Poetry',
#        'Narratives of Masculinity', 'Ethical Themes in Literature',
#        'The Search for Identity', 'Hard-Boiled Fiction',
#        'Intermediate Creative Writing', 'Advanced Composition',
#        'Seventeenth Century Lit', 'Nineteenth Cent Engl Lit',
#        'Amer Lit, 1914 to Present', 'Milton',
#        'Authors: Whitman/Dickison Leg', 'Authors: Lawrence and Joyce',
#        'St in Cinema: Gangsters, Gats', 'Sp St: Modern Irish Literature',
#        'Special Studies in Craft: Time', 'History of the Engl Lang',
#        'Elementary Statistics', 'Calculus IV', 'Intro Higher Mathematics',
#        'Data Structures With C++', 'Combinatorics & Graph Theory',
#        'Complex Variables', 'Differential Equations', 'Real Analysis',
#        'Social and Political Philos', 'Symbolic Logic',
#        'Medieval Philosophy', '19th Century Philosophy',
#        'Philosophy of Mind', 'Ppm: Studies in Leibniz & Hume',
#        'Sem: Nietzsche', 'Values', 'Top in Continentl Thought',
#        'Statistical Methods', 'Statistical Methods Lab',
#        'Experimental Psychology', 'Experiential Methods',
#        'Abnormal Behavior', 'Cognitive Processes', 'Social Psychology',
#        'Seminar: Sensation/Perception', 'Seminar:Psyc of the Internet',
#        'Sem: Cont Psyc Thought in Lit', 'Advanced Organic Lab',
#        'Expressions of Evil', 'Approaches to Study of Lit',
#        'Adv Crtv Writ:Creative Nonfic', 'English Medieval Literature',
#        'English Lit of Romantic Period', 'English Lit, 1900 to Present',
#        'Dramatic Lit: Med/Neo-Class', 'American Studies:Sense of 30s',
#        'SS in Craft:The Prose Poem', 'Orality and Textuality',
#        'Gendered Modernisms', 'ST: Chaotic Dynamical Systems',
#        'Environmental Thinking', 'Philosophers and Philos Mvmnts',
#        'Sem: Genealogies of Morals', 'Psychology of Sex and Gender',
#        'Cross-Cultural Psychology', 'Seminar: Health Psychology',
#        'Seminar: Peace Psychology', 'Seminar:Psychology and Film',
#        'Environmental Chemistry', 'Environmental Chem Lab',
#        'ST: Industrial Organization', 'Modern Intl Short Story',
#        'Adv Creative Writing: Poetry', 'Adv Creative Writing: Fiction',
#        'English Renaissance Literature', 'English Lit - Victorian Period',
#        'Chaucer', 'Lit of Modern Theatre',
#        'SS:African Amer Women Writers', 'SS: Law and Literature',
#        'Women Writers-Engl Renaissance', 'American Cultural Identity',
#        'Mathematical Modeling', 'Geometry', 'Cmplx Variables and Applctn',
#        'Intro to Neural Networks', 'Spec Studies in American Phil',
#        'Sem:Early Math Development', 'Sem: Sensation & Perception',
#        'Sem: Psychoanalytic Thought', 'SS: Global Env & Res Issues',
#        'The Supernatural in Amer Lit', 'Native American Literature',
#        'Restoration and 18C Engl Lit', 'SS: Urban Encounters',
#        'SS: Modern Irish Literature', 'Sem: The Short Story Cycle',
#        'Advanced Japanese', 'ST: Number Theory', 'PPM: Kierkegaard',
#        'Topics in Continental Thought', 'Psychology of Women and Gender',
#        'Field Learning Experience', 'Physiology of Behavior Lab',
#        'Sem: Psychology of Health', 'Sem: Theories of Development',
#        'Sem: Forensic Psychology', 'Sem: Psychology and Film',
#        'Research Experience', 'Tutorial: Theories of Learning',
#        'Tutorial: Statistical Methods', 'Contemporary and Hist Issues',
#        'Advanced Inorganic Chem', 'ATC: Adv Instrumental Lab',
#        'Game Theory', "The Heroine's Text", 'Intro to Postcolonial Lit',
#        'History of the English Lang', 'SA: Whitman, Dickinson Legacy',
#        'SS: Apocalyptic Tradition', 'SS: King Arthur & Round Table',
#        'SS: Anglophone Indian Fiction', 'Sem: Performing Gender',
#        'ST: Cryptography', 'Aesthetics', 'Kant and the 19th Century',
#        'Analytic and Linguistic Phil', "Kant's Moral Philosophy",
#        'Studies in American Philosophy', 'Psychology of Aging',
#        'Sem: Violence-Partner Relatns', 'Applied Macroeconomics',
#        'Global Economics', 'American Poetry As Mosaic',
#        'The Award-Winning Novel', 'Literary Feasts',
#        'Ethical Conflicts in Mod Lit', 'Dramatic Lit: Med-18th Century',
#        'SS: Craft - the Short Story', 'SS: Roots and Tributaries',
#        'SS:Living Spaces of Lit', 'Magician As Creative Artist',
#        'The Sonnet', 'Ethnic American Literature',
#        'ST: History of Mathematics', 'Intro to Feminist Philosophies',
#        "Plato's Republic", 'PP: Contemp Ethical Theories',
#        'PP: Phil & Psyc of Language', 'Introduction to Psychology',
#        'Psychological Statistics', 'Psychological Statistics Lab',
#        'Research Methods in Psychology', 'Cognitive Psychology',
#        'Sem:Environmental Problems', 'Sem:Phil & Psyc of Language',
#        'Psychology and Film', 'Tutorial: Theory of Learning',
#        'Economic Geography', 'Sem in Economic Problems',
#        'Asian American Literature', 'Coming of Age in the US',
#        'Literary London', 'SS: Women Writ- Romantic Per',
#        'SS:Modern/Postmodern Poets', 'SS: The Literature of Empire',
#        'Mathematical Modeling II', 'ST:Computer Graphics',
#        'ST: GraphThry & Part Ord Sets', 'Environmental Aesthetics',
#        'Metaphysics', "PPM: Hume's Treatise", 'SS: Thoreau',
#        'Comparative & Evolutionry Psyc', 'Forensic Psychology',
#        'Sem: Human Memory', 'Advanced General Chemistry',
#        'Advanced General Chemistry Lab', 'Quant Analysis & Chem Equilib',
#        'Instrmntl Methods of Analysis', 'Integrated Advanced Lab I',
#        'ATP: Instrumental Lab', 'SS: Health Economics',
#        'Environ & Nat Resource Econ', 'Literary Histories',
#        'Int Creative Writing (fiction)', 'Int Creative Writing (poetry)',
#        'SS: Defining Borders', 'War, Death, and Prison in Lit',
#        'The Birth of Modernity: 1611', 'The Short Story Cycle',
#        'Engineering Mathematics', 'ST:General Topology',
#        'The Examined Life', 'Environmental Ethics',
#        "ST:Hegel's Moral & Pol Philos", 'Sem: Psyc of Environmntl Probs',
#        'Lab in Child Development', 'Advanced Inorganic Chemistry',
#        'Integrated Advanced Lab II', 'IS: Physical Chemistry Lab',
#        'IS: Inorganic Chemistry Lab', 'SS: SocialSecurity/Med Reform',
#        'Literature and Censorship', 'Narrative Pathologies',
#        'Apocalyptic Themes in Lit', 'Adv Creative Writing (fiction)',
#        'Adv Creative Writing (poetry)', 'SS: Hawthorne and Melville',
#        'SS: The Theatre of War', 'SS: Slavery & Lit Imagination',
#        'SS: The Lyric Essay', 'ST: Evil and Non-violence',
#        'Critical Race Theory', 'Heidegger', "ST: Kant's Crit Pure Reason",
#        'ST: Phil & Psyc of Language', 'Animals and Philosophy',
#        'ST: Thoreau', 'Sem: Cross Cultural Psyc',
#        'Sem: Phil and Psyc of Language', 'Global Environ & Resource Iss',
#        'ST: Econ of Crime&Punishment', 'ST: Econ of Transportation',
#        'The Unfamiliar', 'Lyric Solitudes & Communities',
#        'SS: Amer Dreams/Nightmares', 'SS: Modern Irish Poetry',
#        'Sem: Mirror Talk: Autobiogphy', 'Sem: Is It Any Good?',
#        'Sem: Gendered Modernisms?', 'Senior Project I',
#        'ST:Evil and Non-Violence', 'ST: Conjugal Love', 'ST: Nietzsche',
#        'ST:The Late Foucault', 'Senior Paper', 'Sem:Nonverbal Behavior',
#        'ST:Qualitative Res & Analysis', 'Intro to Environmental Chem',
#        'Environmental Chem & Science', 'ST: Aqueous Geochemistry',
#        'Principles Econ & Environment', 'ST: Applied Microeconomics',
#        'The Meaning of Life', 'King Arthur:Once&Future Hero',
#        'Adv Creative Writing (non-Fic)', 'SA: Whitman and Dickinson',
#        'SS: Lit of Empire & Aftermath', 'SS: First Books of Poems',
#        'Senior Project II', 'ST:Punishmnt & Responsibility',
#        'ST: Reproduction', 'ST: Emerson', 'ST: Intro to Primate Behavior',
#        'Seminar in Peace Psychology', 'Sem:Evolution of Human Mating',
#        'ST: Global Collective Action', 'ST:Development Econ',
#        'Intro Creative Writing', 'Coming of Age in Modern Age',
#        'African-New Wrld Shakespeare', 'Intmd Creative Writing-Fiction',
#        'Intmd Creative Writing-Poetry', 'Restoration & 18C British Lit',
#        'British Lit of Romantic Period', 'SS:Questions-Poetic Influence',
#        'SS:Memoir, Art of Truth&Lies', 'SS: African Amer Wmn Writers',
#        'Sem:Magician-Creative Artist', 'Sem:Wmn Writers of England',
#        'Sem:Cosmopolitansm in Britain', 'Problem Solving in Mathematics',
#        'ST: Philosophical Problems', 'ST:Foundations Non-Violence',
#        'Abnormal Psychology', 'Social Stigma',
#        'Sem: Environmental Problems', 'Applied Psychology & Practicum',
#        'Chemistry of Art', 'Chemistry of Art Lab',
#        'ST:Econ of Crime & Punishment', 'Wine Economics',
#        'Award-Winning Novels', 'Adv Creative Writing-Fiction',
#        'Adv Creative Writing-Poetry', 'British Lit, 1900 to Present',
#        'ST: John Donne', 'ST:A Feast of Narrative Forms',
#        'ST: The Sixties', 'Philosophy of Feminism',
#        'Sem: Cognition and Development', 'ST:Development Economics',
#        'ST:Award-Winning Novels', 'ST:African Amer Literature',
#        'Dramatic Lit: Med-18th Cen', 'ST: EVIL',
#        'ST:American Protest Lit', 'ST:Complicated People',
#        'ST:Return of the King', 'ST:Short Story Cycle',
#        'Third Year Japanese', 'Reproduction',
#        'ST:Contemp Phil of Science', 'ST:Emerson & Nietzsche',
#        'Stereotyp,Prjudice&Intgrp Rel', 'Theories Knowledge Acquistn',
#        'ST:Japanese Psychology', 'ST:Origin of Human Cognition',
#        'Practicum in Psychology', 'Applied Psychology',
#        'IS:Psychology & Everyday Life', 'ST:Polymer Chemistry',
#        'International Finance', 'ST:American Dreams/Nightmares',
#        'ST:American Travel Narratives', 'ST:Hawthorne and Melville',
#        'Colonial & Anti-Colonial Lit', 'ST:Extraordinary Visions',
#        'ST:Slavery in Lit Imagination', 'ST:Memory and Narrative',
#        'ST:Number Theory', 'Math Modeling & Num Methods',
#        'Phenom of Religious Experience', 'Education and Autonomy',
#        'ST:Kierkegaard', 'ST:Heidegger & Levinas',
#        'Theoretical Apprch Psychothrpy', 'Issues in Perception',
#        'ST:Sem in Forensic Psychology', 'ST: Psyc in Media:Facts/Fict',
#        'Organic Lab Techniques I', 'Principles of Microeconomics',
#        'Principles of Macroeconomics', 'Principles Microecon & Enviro',
#        'ST:Jane Austen & her Context', 'The Fictional Civil War',
#        'ST:Ren Lit: World,Flesh,Devil', 'ST:Restoration &18C Brit Fict',
#        'ST:Brit Lit 1900- :CoolBrit', 'ST:Hist of English Language',
#        'ST:Writers Writing Writers', 'ST:Conrad, Nabokov, Rushdie',
#        'ST:Chaos Theory', 'ST:Phil & Psyc of Language', 'Motivation',
#        'Psychology of Learning', 'Psyc of Learning Lab',
#        'Organic Lab Techniques II', 'Adv Analytical Instrumentation',
#        'Crime and Punishment', 'ST:The Shaping Spirit',
#        'ST:Intro to African Amer Lit', 'ST:Medieval Lit: Best Sellers',
#        'ST:Victorian Lit: Vict Beauty', 'ST:Whitman/Dickinson & Legacy',
#        'ST:Rise of the Scottish Novel', 'ST:Black Urban Experience',
#        'ST:Creating Truth', 'ST:Programming with Robots',
#        'ST:Cryptography', 'ST:Punishment& Responsibility',
#        'ST:Shakespeare, Descartes', 'ST:Emerson',
#        'ST:Child & Adolescent Develop', 'ST:Wom Intersection Identity',
#        'Seminar in Human Memory', 'Student Research',
#        'Development Economics', 'Storytell Survivance & Escape',
#        'Death/Desire in Epic & Romance', 'Modernist Deviance & Legacies',
#        'Dram Lit:Medieval Thru 18th C', 'Amer Lit After Amer Century',
#        'Kinship in Native Amer Lit', 'Organic Form & Lit Invention',
#        'The Poetics of Place', 'American Hist, Amer Fiction',
#        'Ulysses, Modernism & Modernity', 'Fourth Year Japanese',
#        'West Phil Trad:Ancient', 'Foundatns American Romanticism',
#        'Language and Meaning', 'Hannah Arendt as Pol Thinker',
#        'Lab in Social Relations', 'Social Relations Lab',
#        'The Witches of Salem', 'How to Read Amer Indian Novel',
#        'Love,Sex,Power in Tudor Engl', 'British Drama', 'Romantic Poetry',
#        'Homage,Betrayal or Different', 'Retell Indian Captivity Narr',
#        'Programming with Robots', 'ST: History of Math',
#        'ST:Punishment &Responsibility', 'ST:Evil and Non-violence',
#        'West Phil Tradition: Modern', 'Contemp American Romanticism',
#        "ST:Hegel's Moral & Pol Phil", 'ST:Wittgenstein',
#        'ST:Nietsche and Heidegger', 'Psychology of Law',
#        'Science of Sexual Orientation', 'Poverty and Child Development',
#        'Instrumental Methods Lab', 'Advanced Chem Synthesis',
#        'ST:Fin Markets & Investments', 'ST: Intro to African Amer Lit',
#        'Adv Creative Writing-Nonfict', 'Studies in British Literature',
#        'ST: Romantic Literature', 'ST: Brit & Irish Modernism',
#        'ST: The 19-Century Amer Novel', 'Amer Lit, 1920-Present',
#        'Humor in Lit Short Story', 'ST: Historical Novels',
#        'Postcol Melchly, Cosmopolitan', "ST: American 1980's",
#        'IS: Tea Ceremony', 'ST:Banality of Evil',
#        'ST:Philosophy in Literature', 'Western Phil Trad: Ancient',
#        "Ethics&Food:What's for Dinner", 'Wittgenstein',
#        "ST: Plato's Republic", 'Psychology Statistics Lab',
#        'ST: Research Methods', 'ST:Educational Psychology',
#        'Res Methods: Cognitive Psyc', 'Chemistry in Art',
#        'Chemistry in Art Lab', 'Organic Chem of Drug Design',
#        'Intro to Lit and Humanities', 'ST: Stdies in Renaissance Lit',
#        'American Lit, 1620-1920', 'The Black Urban Experience',
#        'IS: Japanese Calligraphy', 'ST:Mathematical Modeling',
#        'ST: On Beauty', 'Western Phil Tradition:Modern', 'Emerson',
#        'ST: Introduction to Kant', 'Child and Family Therapy',
#        'Res Methods Psychometrics', 'Res Methods:Povrty &Child Dev',
#        'ST:The Psychology of Writing', 'Computational Biochemistry',
#        'ST:Behavioral Economics', 'ST:Medieval Lit: Journeys',
#        'ST:Restoration/18th Cent Lit', 'ST:British Lit 1900-Present',
#        'ST:Film Noir Modernism', 'ST: For Your Eyes Only',
#        'Dramas of Reading', 'Hawthorne and His Malcontents',
#        'Canadian Hybridity', 'ST:Stats for Scientists',
#        'Banality of Evil', 'ST:Intro to Asian Philosophy',
#        'Western Philosophy Trad:modern', 'ST:Aristotle Being a Person',
#        'ST:Intro to German Philosophy', 'ST:Aesthetics East and West',
#        'Tutorial in Symbolic Logic', 'ST: Sensation and Perception',
#        'Res Methods: Intgrp Relations', 'Intergroup Relations Lab',
#        'Bioinorganic Chemistry', 'ST: Investment',
#        'African-New World Shakespeare', 'ST:Renaissance Literature',
#        'ST: Amer Lit: Odd 50s Novels', 'Literary Theory',
#        'ST:Book History&Print Culture', 'Senior Project',
#        'St: Punish & Responsibility', 'ST: Intro to Indian Phil',
#        'ST:Erotic Wisdom', 'ST:Phil of Kashmir Saivism',
#        'What Is the Human Being?', "Heidegger's Being and Time",
#        'Res Methods: Povrty&Child Dev', 'Seminar in Consciouness',
#        'ST:Political Economy of Women', 'ST: The Iroquois World',
#        'ST: Renaissance Literature', 'ST: Romantic Poetry',
#        'ST: Poe and Hawthorne', 'IS:TeachingImaginativeWriting',
#        "Pynchon's Mason & Dixon", 'Futuristic Fictions',
#        'Statistics With Applications', 'ST: Differential Geometry',
#        'ST: Augustine and Aquinas', 'Adolescent Development',
#        'ST:Psychology of Learning', 'ST:Social Psyc on Well-Being',
#        'Res Methods in Personality', 'Marine & Freshwater Chemistry',
#        'ST:Global Political Economy', 'Investment Theory and Analysis',
#        'Witches of Salem', 'ST: Medieval Literature',
#        'ST: Victorian Poetry', 'ST:British & Irish Modernism',
#        'ST: Reading India', 'Intro to Computer Programming',
#        'Probability Theory', 'Punishment & Responsibility',
#        'Philosophy in Literature', 'Plato', 'ST: Contemporary Pragmatism',
#        'St: Modern Jewish Thought', 'ST:Applied Behavior Analysis',
#        'ST: Social Judgment', 'Issues in Infancy',
#        'Parenting Across Cultures', 'Methods: Educational Psyc',
#        'ST: Behavioral Pharmacology', 'Res Methods:Intgrp Relations',
#        'Microscale Electrophoretic Sep', 'Chemistry Seminar',
#        'Political Economy of Women', 'St: Creative Influence',
#        'ST: British Drama', 'Victorian Literature', 'Writers of Place',
#        'IS: Editing in Practice', 'Scottish Romanticism',
#        'The Faerie Queene', 'Slavery Reviewed',
#        'Independent Study in Geometry', 'Combinatorics',
#        'Statistical Theory', 'Aristotle', 'Philosophy Colloquium',
#        'Research Methods', 'ST: Cross-Cultural Psychology',
#        'Multivariate Stats for Psyc', 'Inorganic Chemistry',
#        'Env Chemistry & Engineering', 'Global Political Economy',
#        'ST: Death and Desire', 'Renaissance Literature',
#        'ST: Contemporary British Lit.', 'Nineteenth Century to Now',
#        'ST: Playwriting', 'ST: Gender and Rhetoric',
#        'St: Postmodern Post Trauma', 'Statistical Modeling',
#        'Erotic Wisdom', 'German Moral Thought', 'Nietzsche and Heidegger',
#        'ST: Positive Psychology', 'Principles Microecon',
#        'Industrial Organizations', 'ST: The HumAnimal',
#        'Intermediate Nonfiction', 'VT:MedievalLit: Social Bodies',
#        'VT:Fear,Anxiety,&Imagination', 'VT: British & Irish Modernism',
#        'ST: Anathem', 'Same River Twice', 'Contemporary American Fiction',
#        'Ulysses, Modernism, Modernity', 'IS: Third-year Japanese',
#        'Math Modeling', 'Heidegger and Architecture',
#        'Educational Psychology', 'Intro to Env Chem & Science',
#        'Behavioral Economics', 'ST: Regulation of Business US',
#        'VT: Arthurian Literature', 'VT: Edens Lost and Found',
#        'ST: Medvl Work Wealth Poverty', 'ST: Rhetorical Bodies',
#        'ST: Philosophy & Foundations', 'ST: Open Source Software Dev',
#        'ST:Intr to Point-set Topology', 'Contemporary Pragmatism',
#        'Poverty & Child Development', 'St: What Is Mental Illness?',
#        'Intro to Computer Programing', 'ST: Human-Computer Interact',
#        'Data Structures', 'VT:Lit Feast: Lyrical Writing',
#        'VT:Ends of Renaissance Lit', 'VT: Social Mutability',
#        'Rhetorical Bodies', 'ST: Iroquois Literature',
#        'ST: Prose and Music', 'VT: Jane Austen & Her Context',
#        'VT: The American Road Novel', 'IS: Software Development II',
#        'ST: Truth and Truthfulness', 'Nature in Modern Phil',
#        'VT: Aristotle on Personhood', 'Psychology and Law',
#        'IS: Behavioral Research', 'IS: Psychology Practicum',
#        'Env Chemistry', 'ST: Env Chem & Engineering',
#        'ST: Elements Computer Systems', 'ST: Algorithm Dsgn & Analysis',
#        'Microeconomics & Environment', 'Industrial Organization',
#        'ST: Theories of Work', 'Intro Creative Nonfiction',
#        'Vt: Before Harry Potter', 'Playwriting/Write Performance',
#        'VT: Old Stories, New Problems', 'VT: The Meanings of Progress',
#        'VT: Contemporary British Lit', 'Drama Lit: 19th Century to Now',
#        'ST: Making Melville', 'ST:Monstrosity Across Culture',
#        'IS: Japanese Caligraphy', 'Bioethics', 'What Is the Human Being',
#        'The Psychology of Prejudice', 'ST: Global Childhoods',
#        'What Is Mental Illnness?', 'Seminar: Psych of Deception',
#        'Computational Prob Solving', 'Computational Prob Solvng',
#        'Discrete Math & Func Prog', 'SW Performance Optimizat',
#        'ST: Artificial Intelligence', 'VT: Reading Minds',
#        'Creative Writing - Nonfiction', 'VT:Love,Sex,&Pwr -Renaissance',
#        'VT: Romantic Poetry', 'VT: Modernist Deviance',
#        'ST: African American Lit', 'VT: Inside/Outside',
#        'VT: Slavery & American Lit', 'ST: Counterexamples in Calc',
#        'The Gift of Art', 'Buddhist Ethics', 'Self and World',
#        'VT: Plato', 'Judith Butler & Philosophy', 'Intro to Env Chem',
#        'Advanced Organic Synthesis', 'Computer Systems Fundamentals',
#        'ST: Software Design', 'St: Natural Lang Processing',
#        'Principles Microecon and Env', 'Intermediate Microeconomics',
#        'VT: Before Harry Potter', 'VT: Writing in the Middle Way',
#        'ST: History of the Book', 'ST: Extaodinary Visions',
#        'ST: Design/Analysis Res Study', 'Queer Friendship',
#        'ST: Kant Critique-Pure Reason', 'Heideggers Being and Time',
#        'IS: Heideggers Being and Time', 'Perspectives on Disgust',
#        'Problem-Solving in Chemistry', 'ST: Simulation Methods&Appl.',
#        'Computer Systems Programming', 'Capstone Project I',
#        'Corporate Finance', 'VT:Satire in American Fiction',
#        'African American Literatures', 'VT: Restoration & 18th C Lit',
#        'VT:British Lit, 1900 - Pres', 'VT: American Lit, 1620-1920',
#        'VT: Poe and Popular Culture', "VT: Cntrpoints:E. Said's Work",
#        'VT: Echo, Riposte, Renewal', 'VT: Playing God', 'ST: Set Theory',
#        'ST: Skept Rel and Truth', 'Philosophy of Science',
#        'Vt: Aristotle on Persons&perso', 'ST: Korsgaard and Her Critics',
#        'ST: Heidegger and Levinas', 'Env Chem',
#        'ST: Software Engineering', 'Theory of Computation',
#        'Algorithm Design & Analysis', 'Artificial Intelligence',
#        'Capstone Project II', 'Advanced Project', 'Honors Project',
#        'Public Economics', 'VT: The Witches of Salem',
#        'Intro to Shakespeare', 'VT: Studies in Renaiss Lit',
#        'Vt: Victorian Lit: Order & Dec', 'VT: American Protest Lit.',
#        'VT:Amer Lit: Mod-Contemporary', 'VT:Lit Thry:Feminist Theory',
#        'VT: Mystery, Murder, & Mayhem', 'VT: Poetry Comics',
#        'Intro East Asian Philosophy', 'Radical Thoughtlessness',
#        'Ethics After Auschwitz', 'Forgiveness', 'Happiness',
#        "ST: Hegel's Moral&Pol Phil", 'ST: Cells to Brain to Mind',
#        'St: Psychology of Crime', 'Human-Computer Interaction',
#        'Native American Literatures', 'VT: Social Bodies',
#        'Amer Lit, Modern-Contemp.', 'VT: Writing Dissent',
#        'VT: Bldg, American, Progress', 'VT: The British Gothic',
#        'ST: Mathematical Logic', 'Skept, Relativism, Truth',
#        'St: Philosophy in Sci. Fiction', 'Cosmopolitanism & Belonging',
#        'Asian Philo of Gender', 'Personality Psychology', 'Comparative',
#        'ST:When is science unreliable', 'Water Chemistry',
#        'ST: Machine Learning', 'Software Design', 'CFA Challenge',
#        'WIC Portfolio Analysis', 'VT: Badass Women, 1559-1668',
#        'VT: Shifting Gr: Wrtg., Exile', 'VTRenaissance:Writing Matters',
#        'VT:American Poetry, 1800-1945', 'VT:Shakepeare:R/W/P/I',
#        'VT:Anti-Colonial Literature', 'Design & Analysis', 'Non-Violence',
#        'Case Studies in Applied Ethics', 'Chinese Philo & Issues',
#        "VT: Plato's Republic", 'Judith Butler', 'Global Health Ethics',
#        'ST: Culture & Social Behavior', 'General Chemistry I',
#        'Comp.Chem: Org. Mol', 'Env Chem & Engineering Lab',
#        'IS: P-Chem Lab Development', 'IS:Env Chem & Engineering',
#        'Natural Language Processing', 'ST: Economics of Sports',
#        'ST: Development Economics', 'VT:Literature and the Digital',
#        'IntroShakes-Work,Wealth,Status', 'Int Creative Writing - Nonfict',
#        'VT: The Birth of Empire', 'VT: Victorian Literature',
#        'VT: Contemporary British Lit.', 'Amer Lit, Modern-Contemporary',
#        'VT:Counterpoints: Edward Said', 'VT:Universe:Poetry/Sci/Math',
#        'VT: Realism and American Fict', 'VT: Donne/Contemporary Poetry',
#        'ST: Philosophy in Sci Fi', 'VT: Aristotle', 'ST: Giorgio Agamben',
#        'Cells to Brain to Mind', 'ST: Dev of School Shooters',
#        'ST: Brain and Language', 'General Chemistry II',
#        'Materials Chemistry', 'ST: Data Analysis', 'Software Design Lab',
#        'ST: International Trade', 'Applied Wine Economics',
#        'Many Magicks', 'Milton and the Idea of Freedom',
#        'VT:Resist. Lit.,Theory& Pol.', 'VT: Making Melville',
#        'Philosophy of Education', 'Hermeneutics', 'St: Moral Emotions',
#        'Psychology of Poverty', 'ST: Emotion',
#        'ST:Culture & Social Behavior', 'IS: Machine Learning',
#        'VT: Reading the Anthropocene', 'VT: Love, Sex, and Power',
#        'VT: Figures of Newness', 'VT: Rethinking American Hist',
#        'VT: Solidarity Literature', 'VT: History of the Book',
#        'VT: Writing the Flash', 'VT: Protest Literature',
#        'IS: Numerical Analysis Python', 'IS: Set Theory',
#        'Philosophy in Science Fiction', 'Greek and Roman Philosophy',
#        'Modern European Philosophy', 'Restorative Justice',
#        'ST: The Analects', 'ST: Intro to Black Psychology',
#        'ST: Health and Wellness', 'Development of School Shooters',
#        'Brain and Language', 'ST: Diversity & Intergrp Rel',
#        'IS: Eating Disorders', 'ST: Data Analysis and Visual.',
#        'ST: Computer Graphics', 'ST: Computer Networks',
#        'ST: Law and Development', 'VT: Infrastructure',
#        'VT: Medieval Literature', 'VT: Romantic Literature',
#        'VT: Cont. Literary Theory', 'IS:Japanese Calligraphy',
#        'IS:Tea Ceremony', 'ST: The Courage of Truth',
#        'IS: Philosophy of Race', 'Drug Design', 'Intro to Data Science',
#        'ST: Intelligent User Interfac', 'ST: Databases w/Web Apps',
#        'VT: American Horror', 'Shakespeare:Love, Sex, Gender',
#        'Intro to African American Lit', 'VT: Violence/Satire/Humor',
#        'VT: Edward Said', 'VT: Out of Our Time: Cr Writ.', '_Ulysses_',
#        'Reinventing Chaucer', 'IS: Calligraphy',
#        'Introduction to Statistics', 'ST: Soc Justice in Hellen Phil',
#        'Emotion', 'Behavioral Neuroscience',
#        'Behavioral Neuroscience Lab', 'Psychological Disorders',
#        'ST: Web Design', 'Computer Simulation Methods',
#        'Optimizing Simulations Methods', 'VT: Anxieties of Empire',
#        'VT: Victorian Grotesques', 'VT: Postmodern Pagemonsters',
#        'VT: American Women Writers', 'VT: Feminist Theory',
#        'VT: Black Shakespeares', 'Creative Thesis',
#        'Modern Japan Lit/Culture', 'East Asian Phil and Goodlife',
#        'The Nature of Persons', "ST: Confucius' Analects",
#        'Psychology of Gender', 'Stereotyping & Prejudice',
#        'ST: Psychology of Food', 'Interactive Computer Graphics',
#        'African American Hist Fict', 'VT: Extraordinary Visions',
#        'VT: The Sonnet', 'Intro to Calculus',
#        'ST: Climate Change Black Indg', 'ST: Justice & Tradns Env Eth',
#        'Frankfurt School', 'ST: Problem-Solving Chem II',
#        'Asymmetric Organic Synthesis', 'ST: Personal Finance',
#        'ST: Fin Time Series Ecnmtrcs', 'VT: Shifting Grounds',
#        'VT: Wicked Problems', 'Warriors, Queens, Enchanters',
#        'VT: Amer Lit Cont Environment', 'VT: Magic Shakespeare',
#        'VT: Shameclosing Eyes', 'Solidarity--Anti-Colonial Lit',
#        'Human-Nonhuman Dynamics', 'ST: Food Justice Sovereignty',
#        'Liberatory Pedagogies', 'ST: The Zhuangzi',
#        'ST: Embodied Cognition', 'Child Abuse and Neglect',
#        'ST: Intimate Partner Violence'], dtype=object)

# %%
# How many course instances (rows) are there for each major?
df_courses["Subject"].value_counts()
# YOUR CODE HERE
# Out:
# Subject
# CHEM    1823
# ENGL    1251
# MATH    1084
# PSYC    1049
# ECON     832
# PHIL     763
# JPNS     283
# CS       201
# Name: count, dtype: int64

# %% [markdown]
# Ok, now that we have that down, let's do some more complex warm-up questions:

# %%
# Last semester (Fall 2022), how many courses were there taught in each Subject/Major?
df_2022=df_courses[df_courses["Term"]=="2022FA"]
df_2022
# Out:
#         Term        Name                   Short Title Subject  Min Cred  \
# 6949  2022FA  CHEM-100-A   Intro to Env Chem & Science    CHEM       3.0
# 6950  2022FA  CHEM-111-A  Problem-Solving in Chemistry    CHEM       1.0
# 6951  2022FA  CHEM-125-A           General Chemistry I    CHEM       3.0
# 6952  2022FA  CHEM-125-B           General Chemistry I    CHEM       3.0
# 6953  2022FA  CHEM-125-C           General Chemistry I    CHEM       3.0
# ...      ...         ...                           ...     ...       ...
# 7103  2022FA  PSYC-420-A  Contemporary and Hist Issues    PSYC       4.0
# 7104  2022FA  PSYC-420-B  Contemporary and Hist Issues    PSYC       4.0
# 7105  2022FA  PSYC-420-C  Contemporary and Hist Issues    PSYC       4.0
# 7106  2022FA  PSYC-495-A                        Thesis    PSYC       3.0
# 7107  2022FA  PSYC-496-A                        Thesis    PSYC       3.0
#
#       Max Cred  Capacity  Active Students Count
# 6949       NaN      35.0                     38
# 6950       NaN      40.0                     22
# 6951       NaN      36.0                     35
# 6952       NaN      36.0                     39
# 6953       NaN      36.0                     37
# ...        ...       ...                    ...
# 7103       NaN      20.0                     18
# 7104       NaN      20.0                     20
# 7105       NaN      17.0                     18
# 7106       NaN      65.0                     48
# 7107       NaN      40.0                      8
#
# [159 rows x 8 columns]

# %%
# Last semester (Fall 2022), what was the largest course?
df_2022[df_2022["Active Students Count"]==df_2022['Active Students Count'].max()]
# Out:
#         Term        Name Short Title Subject  Min Cred  Max Cred  Capacity  \
# 7106  2022FA  PSYC-495-A      Thesis    PSYC       3.0       NaN      65.0
#
#       Active Students Count
# 7106                     48

# %%
# Last semester (Fall 2022), which of the  majors in this dataset had the highest and the lowest average class size?
df_2022.groupby('Subject')["Active Students Count"].min()
# YOUR CODE HERE
# Out:
# Subject
# CHEM    1
# CS      1
# ECON    6
# ENGL    6
# JPNS    0
# MATH    1
# PHIL    1
# PSYC    2
# Name: Active Students Count, dtype: int64

# %%
# Last semester (Fall 2022), pick a Subject/Major and determine the percent of classes with fewer than 20 students
df_2022_CS=df_2022[df_2022['Subject']=='CS']
df_2022_CS
# YOUR CODE HERE
# Out:
#         Term      Name                    Short Title Subject  Min Cred  \
# 6992  2022FA  CS-167-A      Computational Prob Solvng      CS       4.0
# 6993  2022FA  CS-167-B      Computational Prob Solvng      CS       4.0
# 6994  2022FA  CS-215-A          Intro to Data Science      CS       4.0
# 6995  2022FA  CS-220-A      Discrete Math & Func Prog      CS       3.0
# 6996  2022FA  CS-270-A                Data Structures      CS       4.0
# 6997  2022FA  CS-270-B                Data Structures      CS       4.0
# 6998  2022FA  CS-310-A   Computer Systems Programming      CS       4.0
# 6999  2022FA  CS-320-A          Theory of Computation      CS       3.0
# 7000  2022FA  CS-360-A  Interactive Computer Graphics      CS       3.0
# 7001  2022FA  CS-481-A              Independent Study      CS       1.0
# 7002  2022FA  CS-481-B              Independent Study      CS       1.0
# 7003  2022FA  CS-481-C              Independent Study      CS       1.0
# 7004  2022FA  CS-495-A             Capstone Project I      CS       2.0
# 7005  2022FA  CS-496-A            Capstone Project II      CS       2.0
#
#       Max Cred  Capacity  Active Students Count
# 6992       NaN      30.0                     27
# 6993       NaN      30.0                     29
# 6994       NaN      24.0                     12
# 6995       NaN      24.0                     31
# 6996       NaN      24.0                     20
# 6997       NaN      16.0                      8
# 6998       NaN      20.0                     21
# 6999       NaN      20.0                     16
# 7000       NaN      24.0                     21
# 7001       4.0      30.0                      1
# 7002       4.0      30.0                      1
# 7003       4.0      30.0                      2
# 7004       NaN      16.0                     14
# 7005       NaN      16.0                      3

# %%
# CHALLENGE: Write a function that takes in a list of courses (i.e. ["CS-270-A", "CS-310-A", "CHEM-125-A"])
# and returns the mean experienced class size for a student in those classes
len(df_2022_CS[df_2022_CS["Active Students Count"]<20])/len(df_2022_CS)
# Out:
# 0.5714285714285714

# %%
def mean_exp(course_list, df):
    course_size=[]
    for course in course_list:
        avg_size=df[df["Name"]==course]["Active Students Count"].mean()
    print("mean experienced class size"+str(np.mean(course_sizes)))
    print("mean course sizes: ")
    print(course_size)

# %% [markdown]
# ## Part 2: Visualizing the data
#
# Now, this is fun... but we can also use VISUALIZATIONS to explore the data.
#
# First, let's consider the *distributions* of the course sizes.
#
# How might we use visualizations to examine each Subject/Major?
#
# We could start by making a histogram for each one...

# %%
# Make a histogram of the course sizes (for all subjects, all years together)
# What do you notice?
plt.hist(df_courses["Active Students Count"],bins=10)
# Out:
# (array([2.854e+03, 2.130e+03, 1.600e+03, 5.110e+02, 1.540e+02, 1.800e+01,
#         8.000e+00, 3.000e+00, 2.000e+00, 6.000e+00]),
#  array([ 0. ,  9.2, 18.4, 27.6, 36.8, 46. , 55.2, 64.4, 73.6, 82.8, 92. ]),
#  <BarContainer object of 10 artists>)

# %%
# Drop any course that only has 0 or 1 student in it
# You can either make a new data frame or modify the existing one
df_courses[df_courses["Active Students Count"]==0]
# Out:
#         Term        Name              Short Title Subject  Min Cred  Max Cred  \
# 23    2000FA  CHEM-481-A  Adv Topics in Chemistry    CHEM       3.0       NaN
# 25    2000FA  CHEM-490-B                 Research    CHEM       1.0       3.0
# 27    2000FA  CHEM-490-D                 Research    CHEM       1.0       3.0
# 29    2000FA  CHEM-490-F                 Research    CHEM       1.0       3.0
# 30    2000FA  CHEM-498-A            Honors Thesis    CHEM       3.0       NaN
# ...      ...         ...                      ...     ...       ...       ...
# 7255  2023SP  PHIL-484-B        Independent Study    PHIL       1.0       4.0
# 7277  2023SP  PSYC-408-B        Independent Study    PSYC       1.0       3.0
# 7278  2023SP  PSYC-408-C        Independent Study    PSYC       1.0       3.0
# 7279  2023SP  PSYC-408-D        Independent Study    PSYC       1.0       3.0
# 7281  2023SP  PSYC-408-G        Independent Study    PSYC       1.0       3.0
#
#       Capacity  Active Students Count
# 23        10.0                      0
# 25        10.0                      0
# 27        10.0                      0
# 29        10.0                      0
# 30        10.0                      0
# ...        ...                    ...
# 7255      10.0                      0
# 7277      20.0                      0
# 7278      20.0                      0
# 7279      20.0                      0
# 7281      20.0                      0
#
# [492 rows x 8 columns]

# %%
df_courses[df_courses["Active Students Count"]==1]
# Out:
#         Term        Name        Short Title Subject  Min Cred  Max Cred  \
# 21    2000FA  CHEM-451-A  Independent Study    CHEM       1.0       3.0
# 24    2000FA  CHEM-490-A           Research    CHEM       1.0       3.0
# 26    2000FA  CHEM-490-C           Research    CHEM       1.0       3.0
# 28    2000FA  CHEM-490-E           Research    CHEM       1.0       3.0
# 47    2000FA  ECON-493-B   Directed Reading    ECON       2.0       4.0
# ...      ...         ...                ...     ...       ...       ...
# 7256  2023SP  PHIL-484-C  Independent Study    PHIL       1.0       4.0
# 7257  2023SP  PHIL-484-D  Independent Study    PHIL       1.0       4.0
# 7280  2023SP  PSYC-408-E  Independent Study    PSYC       1.0       3.0
# 7282  2023SP  PSYC-408-H  Independent Study    PSYC       1.0       3.0
# 7283  2023SP  PSYC-408-I  Independent Study    PSYC       1.0       3.0
#
#       Capacity  Active Students Count
# 21        10.0                      1
# 24        10.0                      1
# 26        10.0                      1
# 28        10.0                      1
# 47         1.0                      1
# ...        ...                    ...
# 7256      10.0                      1
# 7257      10.0                      1
# 7280      20.0                      1
# 7282      20.0                      1
# 7283      20.0                      1
#
# [744 rows x 8 columns]

# %%
# Now redraw the histogram -- how is it different?

# YOUR CODE HERE

# %%
# Pick any Subject/Major you like
# Make a histogram of the class sizes for that Major
plt.hist(df_courses[df_courses["Subject"]=="CS"]["Active Students Count"],bins=10)
# Out:
# (array([54.,  8.,  7.,  7.,  8., 21., 33., 26., 21., 16.]),
#  array([ 0. ,  3.1,  6.2,  9.3, 12.4, 15.5, 18.6, 21.7, 24.8, 27.9, 31. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# Or, we could put multiple majors on one histogram.
#
# Let's try that out...

# %%
# Pick three Majors and plot histograms of their course sizes on the same plot...
plt.hist(df_courses[df_courses["Subject"]=="CHEM"]["Active Students Count"],density=True, alpha=0.5)
plt.hist(df_courses[df_courses["Subject"]=="CS"]["Active Students Count"],density=True, alpha=0.5)

# YOUR CODE HERE
# Out:
# (array([0.08666346, 0.01283903, 0.01123415, 0.01123415, 0.01283903,
#         0.03370246, 0.052961  , 0.04172685, 0.03370246, 0.02567806]),
#  array([ 0. ,  3.1,  6.2,  9.3, 12.4, 15.5, 18.6, 21.7, 24.8, 27.9, 31. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## Part 3: Introducing Seaborn
#
# Ok, we are getting closer... But is there a better way? Let's try some of the plots we can make with Seaborn.
#
# __What is Seaborn?__
#
# Seaborn is a visualization package that runs on top of Matplotlib. It is specially designed for statistical analysis and for exploring distributions in data. You can find out more at: https://seaborn.pydata.org/. A great place to start is the [Seaborn Tutorial](https://seaborn.pydata.org/tutorial/introduction.html).
#
# __Installation__
#
# Depending on your Anaconda installation, you may need to install the package.
#
# First, try running the import code block below. If it works, great!
#
# If it doesn't work, open up a terminal and run this to install:
#
#     conda install seaborn

# %%
# import Seaborn
import seaborn as sns

# %% [markdown]
# The next part is new, so follow along as best you can.
#
# You don't need to know everything (I certainly don't!). Just get comfortable trying to figure our how these plots work by consulting the [Seaborn documentation](https://seaborn.pydata.org/tutorial.html) and looking for examples that help you understand.

# %%
# We can use a seaborn .distplot()
# It's basically the same as a matplotlib histogram
# We can put all of the Subjects/Majors on one plot:
sns.displot(df_courses,x='Active Students Count')
#sns.displot(df_courses, x="Active Students Count")
# Out:
# /Users/tenzinuden/anaconda3/lib/python3.9/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# Or we could show just one major
sns.displot(df_courses[df_courses["Subject"]=='CS'],x='Active Students Count')

#sns.displot(df_courses[df_courses["Subject"] == "CS"], x="Active Students Count", hue="Subject")
# Out:
# /Users/tenzinuden/anaconda3/lib/python3.9/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# Or we could show them all...
# But this is messy (although note how easy it is to make!)
sns.displot(df_courses,x='Active Students Count',hue='Subject')

#sns.displot(df_courses, x="Active Students Count", hue="Subject")
# Out:
# /Users/tenzinuden/anaconda3/lib/python3.9/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# And here we are normalizing:
sns.displot(df_courses,x='Active Students Count',hue="")

#sns.displot(df_courses, x="Active Students Count", hue="Subject", stat="probability")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 2
#       1 # And here we are normalizing:
# ----> 2 sns.displot(df_courses,x='Active Students Count',hue="")
#
# File ~/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2125, in displot(data, x, y, hue, row, col, weights, kind, rug, rug_kws, log_scale, legend, palette, hue_order, hue_norm, color, col_wrap, row_order, col_order, height, aspect, facet_kws, **kwargs)
#    2111 def displot(
#    2112     data=None, *,
#    2113     # Vector variables
#    (...)
#    2122     **kwargs,
#    2123 ):
# -> 2125     p = _DistributionFacetPlotter(
#    2126         data=data,
#    2127         variables=_DistributionFacetPlotter.get_semantics(locals())
#    2128     )
#    2130     p.map_hue(palette=palette, order=hue_order, norm=hue_norm)
#    2132     _check_argument("kind", ["hist", "kde", "ecdf"], kind)
#
# File ~/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:113, in _DistributionPlotter.__init__(self, data, variables)
#     107 def __init__(
#     108     self,
#     109     data=None,
#     110     variables={},
#     111 ):
# --> 113     super().__init__(data=data, variables=variables)
#
# File ~/anaconda3/lib/python3.9/site-packages/seaborn/_oldcore.py:640, in VectorPlotter.__init__(self, data, variables)
#     635 # var_ordered is relevant only for categorical axis variables, and may
#     636 # be better handled by an internal axis information object that tracks
#     637 # such information and is set up by the scale_* methods. The analogous
#     638 # information for numeric axes would be information about log scales.
#     639 self._var_ordered = {"x": False, "y": False}  # alt., used DefaultDict
# --> 640 self.assign_variables(data, variables)
#     642 for var, cls in self._semantic_mappings.items():
#     643
#     644     # Create the mapping function
#     645     map_func = partial(cls.map, plotter=self)
#
# File ~/anaconda3/lib/python3.9/site-packages/seaborn/_oldcore.py:701, in VectorPlotter.assign_variables(self, data, variables)
#     699 else:
#     700     self.input_format = "long"
# --> 701     plot_data, variables = self._assign_variables_longform(
#     702         data, **variables,
#     703     )
#     705 self.plot_data = plot_data
#     706 self.variables = variables
#
# File ~/anaconda3/lib/python3.9/site-packages/seaborn/_oldcore.py:938, in VectorPlotter._assign_variables_longform(self, data, **kwargs)
#     933 elif isinstance(val, (str, bytes)):
#     934
#     935     # This looks like a column name but we don't know what it means!
#     937     err = f"Could not interpret value `{val}` for parameter `{key}`"
# --> 938     raise ValueError(err)
#     940 else:
#     941
#     942     # Otherwise, assume the value is itself data
#     943
#     944     # Raise when data object is present and a vector can't matched
#     945     if isinstance(data, pd.DataFrame) and not isinstance(val, pd.Series):
#
# ValueError: Could not interpret value `` for parameter `hue`

# %%
# We can also make a continuous plot
# This is using "kernel density estimation" to smooth out the histogram
# More at: https://en.wikipedia.org/wiki/Kernel_density_estimation

sns.displot(df_courses, x="Active Students Count", kind="kde")

# %%
# Maybe it will be easier to see all of the courses if we use our smooth kernel density (kde) plot

sns.displot(df_courses, x="Active Students Count", kind="kde", hue="Subject")

# %% [markdown]
# To really up our game, let's visualize the Subjects/Majors separately.
#
# To do this, let's play with a **catplot** -- which stands for categorical plot. This is useful for dealing with categorical data, like the different Subjects and Courses that we have in this data set. For more on catplot, check out: https://seaborn.pydata.org/generated/seaborn.catplot.html

# %%
# A basic catplot showing the distributions...
# Notice how every course (row) becomes a dot

sns.catplot(data=df_courses, x="Subject", y="Active Students Count")

# %%
# Ok, that is a good start... let's try adding a jitter and making it transparent

sns.catplot(data=df_courses, x="Subject", y="Active Students Count", alpha=0.25, jitter=True)

# %%
# This is a little messy, so let's try it with just the courses last semester

sns.catplot(data=df_2022, x="Subject", y="Active Students Count", alpha=0.5)

# %%
# With this smaller dataset, we can also try a swarmplot
# Notice the difference?

sns.swarmplot(data=df_2022, x="Subject", y="Active Students Count")

# %% [markdown]
# How else might we visualize distributions? We could do a box plot, also known as a box and whiskers plot. ([This post](https://www.khanacademy.org/math/statistics-probability/summarizing-quantitative-data/box-whisker-plots/a/box-plot-review) has a nice refresher on how box plots work.)

# %%
# We can change kind to "box"
sns.catplot(data=df_courses, x="Subject", y="Active Students Count", kind="box")

# %%
# Or we could do a bar plot with errors
sns.catplot(data=df_courses, x="Subject", y="Active Students Count", kind="bar")

# %%
# Or a violin plot (which is kind of like a box plot, but continuous)
sns.catplot(data=df_courses, x="Subject", y="Active Students Count", kind="violin")

# %% [markdown]
# Notice how the different plots emphasize different features of the distributions.
#
# For example, the violin emphasizes many of the courses seems to have "lumps" --- these might be common course caps (12, 25, etc.).
#
# And the bar chart really emphasizes the means.
#
# What do the other visualizations empahsize?

# %%
# What are some other ways we can explore distributions?

# %%
# We could also make a grid of histograms

sns.displot(df_courses, x="Active Students Count", col="Subject", col_wrap=2, height=2, aspect=2)

# %%
# We can also look at a BIVARIATE DISTRIBUTION...
# That is, distribution according to two different variables at once

# Let's look at the distribution of class size by term (semester) 

sns.displot(df_courses, y="Active Students Count", x="Term")

# %%
# Oof, that's really ugly! Let's set the figure size

my_plot = sns.displot(df_courses, y="Active Students Count", x="Term", height=8, aspect=1.5)

# And rotate the x-axes labels
plt.xticks(rotation=45)
plt.show()

# I'm showing you this not because you need to know this, but because these are the things that
# Will come up as you work on making plots :P

# %% [markdown]
# ## Part 4: Time series
# These plots aren't really great for looking at trends over time. Right now, "Term" is categorical. Can we turn it into a date-time object?

# %%
# Add three new columns into your data frame:
# Year
# Month
# Day

# For our purposes, you can assume that the Fall semester starts on August 1 
# and the Spring semester stats on January 1

# YOUR CODE HERE
df_year["year"]=df_courses["Term"]

# %%
# Now, use pd.to_datetime to make a new column, "Date", that is a datetime object
# using the "Day" "Month" and "Year" info
# Remember pd.to_datetime: https://pandas.pydata.org/docs/reference/api/pandas.to_datetime.html

# YOUR CODE HERE

# %%
# Let's make a bar chart showing the average class size over time

#fig, axs = plt.subplots(figsize=(10, 4))

#df_courses.groupby(df_courses["Date"])["Active Students Count"].mean().plot(kind='bar', rot=90, ax=axs)


#plt.xlabel("Semester")  # custom x label using Matplotlib

#plt.ylabel("Average Class Size")

# %%
# Or we could do a line
#fig, axs = plt.subplots(figsize=(20, 4))

#df_courses.groupby(df_courses["Date"])["Active Students Count"].mean().plot(kind='line', rot=90, ax=axs)


#plt.xlabel("Semester")  # custom x label using Matplotlib

#plt.ylabel("Average Class Size")

# %%
# What about plotting the **distribution** over time?
# This is what Seaborn does well!

#sns.lineplot(x="Date", y="Active Students Count", data=df_courses)

# %%
# We can also look at the different Subjects/Majors

#sns.lineplot(x="Date", y="Active Students Count", hue="Subject", data=df_courses)

# %%
# Wow, that's messy! Let's clean it up
# We can put the plots onto a grid
# To do this, we use .relplot()

#g = sns.relplot(
#    data=df_courses,
#    x="Date", y="Active Students Count", col="Subject", hue="Subject",
#    kind="line", col_wrap=2, height=2, aspect=1.5, legend=False,)

# %%
# What if we just want to look at the past 5 years?
# Now that we have a datetime object, we can use a Boolean selector!

#recent_classes = df_courses[df_courses["Date"] >= "01-01-2018"]

#g = sns.relplot(
#    data=recent_classes,
#    x="Date", y="Active Students Count", col="Subject", hue="Subject",
#    kind="line", col_wrap=2, height=2, aspect=1.5, legend=False,)

# %%
# CHALLENGE: What else can you do with this data?

# You might try...
# A: Coming up with an interesting question and answering it
# B: Making a useful function (i.e. our mean expereinced class size estimator)
# C: Making an exploratory visualiation

# What else might you want to do?
